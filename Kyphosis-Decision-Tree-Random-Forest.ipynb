# %% [markdown]
# # CODE TO CLASSIFY KYPHOSIS DISEASE USING DECISION TREES AND RANDOM FOREST CLASSIFIER

# %% [markdown]
# # PROBLEM STATEMENT

# %% [markdown]
# - Kyphosis is an abnormally excessive convex curvature of the spine. The kyphosis data frame has 81 rows and 4 columns. representing data on children who have had corrective spinal surgery. Dataset contains 3 inputs and 1 output
#
# INPUTS:
# - Age: in months
# - Number: the number of vertebrae involved
# - Start: the number of the first (topmost) vertebra operated on.
#
# OUTPUTS:
# - Kyphosis: a factor with levels absent present indicating if a kyphosis (a type of deformation) was present after the operation.

# %% [markdown]
# # STEP #0: LIBRARIES IMPORT ( 1 mark)

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.preprocessing import LabelEncoder
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.tree import DecisionTreeClassifier
from sklearn.metrics import confusion_matrix, classification_report
from sklearn.ensemble import RandomForestClassifier

# %% [markdown]
# # STEP #1: IMPORT DATASET (1 marks)

# %%
data = pd.read_csv("kyphosis.csv")
data.head(10)
# Out:
#   Kyphosis  Age  Number  Start
# 0   absent   71       3      5
# 1   absent  158       3     14
# 2  present  128       4      5
# 3   absent    2       5      1
# 4   absent    1       4     15
# 5   absent    1       2     16
# 6   absent   61       2     17
# 7   absent   37       3     16
# 8   absent  113       2     16
# 9  present   59       6     12

# %%
#question
# Out:
#   Kyphosis  Age  Number  Start
# 0   absent   71       3      5
# 1   absent  158       3     14
# 2  present  128       4      5
# 3   absent    2       5      1
# 4   absent    1       4     15
# 5   absent    1       2     16
# 6   absent   61       2     17
# 7   absent   37       3     16
# 8   absent  113       2     16
# 9  present   59       6     12

# %%
#question
# Out:
#    Kyphosis  Age  Number  Start
# 76  present  157       3     13
# 77   absent   26       7     13
# 78   absent  120       2     13
# 79  present   42       7      6
# 80   absent   36       4     13

# %%
data.tail()
# Out:
#    Kyphosis  Age  Number  Start
# 76  present  157       3     13
# 77   absent   26       7     13
# 78   absent  120       2     13
# 79  present   42       7      6
# 80   absent   36       4     13

# %%
#question
# Out:
#               Age     Number      Start
# count   81.000000  81.000000  81.000000
# mean    83.654321   4.049383  11.493827
# std     58.104251   1.619423   4.883962
# min      1.000000   2.000000   1.000000
# 25%     26.000000   3.000000   9.000000
# 50%     87.000000   4.000000  13.000000
# 75%    130.000000   5.000000  16.000000
# max    206.000000  10.000000  18.000000

# %%
data.describe()
# Out:
#               Age     Number      Start
# count   81.000000  81.000000  81.000000
# mean    83.654321   4.049383  11.493827
# std     58.104251   1.619423   4.883962
# min      1.000000   2.000000   1.000000
# 25%     26.000000   3.000000   9.000000
# 50%     87.000000   4.000000  13.000000
# 75%    130.000000   5.000000  16.000000
# max    206.000000  10.000000  18.000000

# %%
#question
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 81 entries, 0 to 80
# Data columns (total 4 columns):
# Kyphosis    81 non-null object
# Age         81 non-null int64
# Number      81 non-null int64
# Start       81 non-null int64
# dtypes: int64(3), object(1)
# memory usage: 2.6+ KB

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 81 entries, 0 to 80
# Data columns (total 4 columns):
# Kyphosis    81 non-null object
# Age         81 non-null int64
# Number      81 non-null int64
# Start       81 non-null int64
# dtypes: int64(3), object(1)
# memory usage: 2.6+ KB

# %% [markdown]
# # STEP #2: VISUALIZE DATASET (5 marks)

# %%
#question

# %%
sns.countplot(data['Kyphosis'], label = "Count")

# %%
LabelEncoder_y = LabelEncoder()
data['Kyphosis'] = LabelEncoder_y.fit_transform(data['Kyphosis'])
data.head(10)
# Out:
#    Kyphosis  Age  Number  Start
# 0         0   71       3      5
# 1         0  158       3     14
# 2         1  128       4      5
# 3         0    2       5      1
# 4         0    1       4     15
# 5         0    1       2     16
# 6         0   61       2     17
# 7         0   37       3     16
# 8         0  113       2     16
# 9         1   59       6     12

# %%
#question
# Out:
#     Kyphosis  Age  Number  Start
# 0          0   71       3      5
# 1          0  158       3     14
# 2          1  128       4      5
# 3          0    2       5      1
# 4          0    1       4     15
# 5          0    1       2     16
# 6          0   61       2     17
# 7          0   37       3     16
# 8          0  113       2     16
# 9          1   59       6     12
# 10         1   82       5     14
# 11         0  148       3     16
# 12         0   18       5      2
# 13         0    1       4     12
# 14         0  168       3     18
# 15         0    1       3     16
# 16         0   78       6     15
# 17         0  175       5     13
# 18         0   80       5     16
# 19         0   27       4      9
# 20         0   22       2     16
# 21         1  105       6      5
# 22         1   96       3     12
# 23         0  131       2      3
# 24         1   15       7      2
# 25         0    9       5     13
# 26         0    8       3      6
# ...

# %%
present = data[data['Kyphosis']==1]
absent = data[data['Kyphosis']==0]

# %%
#question
# Out:
# Disease present after operation percentage = 20.98765432098765 %

# %%
print("Disease present after operation percentage = {} %".format((len(present)/len(data))*100))
# Out:
# Disease present after operation percentage = 20.98765432098765 %

# %%
#question

# %%
plt.figure(figsize=(10,10)) 
sns.heatmap(data.corr(), annot=True)

# %%
#question

# %%
sns.pairplot(data, hue='Kyphosis', vars = ['Age', 'Number', 'Start'])

# %% [markdown]
# # STEP #3: CREATE TESTING AND TRAINING DATASET/DATA CLEANING (2 marks)

# %%
X = data.drop(['Kyphosis'],axis=1)
y = data['Kyphosis']

# %%
X.head(10)
# Out:
#    Age  Number  Start
# 0   71       3      5
# 1  158       3     14
# 2  128       4      5
# 3    2       5      1
# 4    1       4     15
# 5    1       2     16
# 6   61       2     17
# 7   37       3     16
# 8  113       2     16
# 9   59       6     12

# %%
#question
# Out:
#     Age  Number  Start
# 0    71       3      5
# 1   158       3     14
# 2   128       4      5
# 3     2       5      1
# 4     1       4     15
# 5     1       2     16
# 6    61       2     17
# 7    37       3     16
# 8   113       2     16
# 9    59       6     12
# 10   82       5     14
# 11  148       3     16
# 12   18       5      2
# 13    1       4     12
# 14  168       3     18
# 15    1       3     16
# 16   78       6     15
# 17  175       5     13
# 18   80       5     16
# 19   27       4      9
# 20   22       2     16
# 21  105       6      5
# 22   96       3     12
# 23  131       2      3
# 24   15       7      2
# 25    9       5     13
# 26    8       3      6
# 27  100       3     14
# 28    4       3     16
# 29  151       2     16
# ..  ...     ...    ...
# 51    9       2     17
# 52  139      10      6
# 53    2       2     17
# 54  140       4     15
# 55   72       5     15
# 56    2       3     13
# 57  120       5      8
# 58   51       7      9
# ...

# %%
y.head(10)
# Out:
# 0    0
# 1    0
# 2    1
# 3    0
# 4    0
# 5    0
# 6    0
# 7    0
# 8    0
# 9    1
# Name: Kyphosis, dtype: int32

# %%
#question
# Out:
# 0     0
# 1     0
# 2     1
# 3     0
# 4     0
# 5     0
# 6     0
# 7     0
# 8     0
# 9     1
# 10    1
# 11    0
# 12    0
# 13    0
# 14    0
# 15    0
# 16    0
# 17    0
# 18    0
# 19    0
# 20    0
# 21    1
# 22    1
# 23    0
# 24    1
# 25    0
# 26    0
# 27    0
# 28    0
# 29    0
#      ..
# 51    0
# 52    1
# 53    0
# 54    0
# 55    0
# 56    0
# 57    1
# 58    0
# 59    0
# 60    1
# 61    1
# 62    0
# 63    0
# 64    0
# 65    0
# 66    0
# 67    0
# 68    0
# 69    0
# 70    0
# 71    0
# 72    0
# 73    0
# 74    0
# 75    0
# 76    1
# 77    0
# 78    0
# 79    1
# 80    0
# Name: Kyphosis, Length: 81, dtype: int32

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3)

# %%
sc = StandardScaler()
X_train = sc.fit_transform(X_train)
X_test = sc.transform(X_test)
# Out:
# C:\Users\Ananda\Anaconda3\lib\site-packages\sklearn\preprocessing\data.py:645: DataConversionWarning: Data with input dtype int64 were all converted to float64 by StandardScaler.
#   return self.partial_fit(X, y)
# C:\Users\Ananda\Anaconda3\lib\site-packages\sklearn\base.py:464: DataConversionWarning: Data with input dtype int64 were all converted to float64 by StandardScaler.
#   return self.fit(X, **fit_params).transform(X)
# C:\Users\Ananda\Anaconda3\lib\site-packages\ipykernel_launcher.py:3: DataConversionWarning: Data with input dtype int64 were all converted to float64 by StandardScaler.
#   This is separate from the ipykernel package so we can avoid doing imports until

# %% [markdown]
# # STEP#4: TRAINING THE MODEL (5 marks)

# %%
classifier = DecisionTreeClassifier(criterion = 'entropy')
classifier.fit(X_train,y_train)
# Out:
# DecisionTreeClassifier(class_weight=None, criterion='entropy', max_depth=None,
#             max_features=None, max_leaf_nodes=None,
#             min_impurity_decrease=0.0, min_impurity_split=None,
#             min_samples_leaf=1, min_samples_split=2,
#             min_weight_fraction_leaf=0.0, presort=False, random_state=None,
#             splitter='best')

# %% [markdown]
# # STEP#5: EVALUATING THE MODEL (3 marks)

# %%
y_pred = classifier.predict(X_test)
cm = confusion_matrix(y_test, y_pred)
print(cm)
# Out:
# [[16  4]
#  [ 2  3]]

# %%
print(classification_report(y_test, y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.89      0.80      0.84        20
#            1       0.43      0.60      0.50         5
#
#    micro avg       0.76      0.76      0.76        25
#    macro avg       0.66      0.70      0.67        25
# weighted avg       0.80      0.76      0.77        25

# %% [markdown]
# # STEP#6: IMPROVING THE MODEL (3 marks)

# %%
RandomForest = RandomForestClassifier(n_estimators=150)
RandomForest.fit(X_train, y_train)
# Out:
# RandomForestClassifier(bootstrap=True, class_weight=None, criterion='gini',
#             max_depth=None, max_features='auto', max_leaf_nodes=None,
#             min_impurity_decrease=0.0, min_impurity_split=None,
#             min_samples_leaf=1, min_samples_split=2,
#             min_weight_fraction_leaf=0.0, n_estimators=150, n_jobs=None,
#             oob_score=False, random_state=None, verbose=0,
#             warm_start=False)

# %%
y_pred = RandomForest.predict(X_test)
cm = confusion_matrix(y_test, y_pred)
sns.heatmap(cm, annot=True)

# %%
print(classification_report(y_test, y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.86      0.90      0.88        20
#            1       0.50      0.40      0.44         5
#
#    micro avg       0.80      0.80      0.80        25
#    macro avg       0.68      0.65      0.66        25
# weighted avg       0.79      0.80      0.79        25

# %% [markdown]
# # EXCELLENT JOB!
